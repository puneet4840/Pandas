# %% [markdown]
# # describe() method: To get statistical details of Data Frame and Series.

# %%
from pandas import *

# %%
df=read_csv('E:\Records.csv').head(15)
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub-Saharan Africa                 Angola        Household
# 7                  Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub-Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# ...

# %%
df.describe()
# Out:
#            Order ID  Units Sold  Unit Price
# count  1.500000e+01    15.00000   15.000000
# mean   5.895579e+08  5467.20000  284.026000
# std    2.876020e+08  2861.93187  243.635788
# min    1.154567e+08   124.00000    9.330000
# 25%    4.278695e+08  3571.00000  109.280000
# 50%    6.166071e+08  5062.00000  205.700000
# 75%    8.235565e+08  8092.00000  453.245000
# max    9.638815e+08  9925.00000  668.270000

# %%
df.min()
# Out:
# Region                  Asia
# Country               Angola
# Item Type          Baby Food
# Sales Channel        Offline
# Order Priority             C
# Order Date        02-01-2013
# Order ID           115456712
# Ship Date         02-06-2013
# Units Sold               124
# Unit Price              9.33
# dtype: object

# %%
df.max()
# Out:
# Region            Sub-Saharan Africa
# Country                       Tuvalu
# Item Type                 Vegetables
# Sales Channel                 Online
# Order Priority                     M
# Order Date                 8/22/2012
# Order ID                   963881480
# Ship Date                  9/15/2012
# Units Sold                      9925
# Unit Price                    668.27
# dtype: object

# %% [markdown]
# # info() method: To get the basic info like columns, rows, columns_name, total size, null values etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          15 non-null     object
#  1   Country         15 non-null     object
#  2   Item Type       15 non-null     object
#  3   Sales Channel   15 non-null     object
#  4   Order Priority  15 non-null     object
#  5   Order Date      15 non-null     object
#  6   Order ID        15 non-null     int64
#  7   Ship Date       15 non-null     object
#  8   Units Sold      15 non-null     int64
#  9   Unit Price      15 non-null     float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 844.0+ bytes
