# %%
from pandas import *

# %% [markdown]
# # Columns

# %% [markdown]
# ## Column Selection

# %%
df=read_csv("E:\Records2.csv").head(11)
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe              NaN
# 4                  Sub-Saharan Africa                 Rwanda              NaN
# 5               Australia and Oceania        Solomon Islands              NaN
# 6                  Sub-Saharan Africa                 Angola              NaN
# 7                  Sub-Saharan Africa           Burkina Faso              NaN
# 8                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub-Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
#
# ...

# %%
df[['Region','Country']]
# Out:
#                                Region                Country
# 0               Australia and Oceania                 Tuvalu
# 1   Central America and the Caribbean                Grenada
# 2                              Europe                 Russia
# 3                  Sub-Saharan Africa  Sao Tome and Principe
# 4                  Sub-Saharan Africa                 Rwanda
# 5               Australia and Oceania        Solomon Islands
# 6                  Sub-Saharan Africa                 Angola
# 7                  Sub-Saharan Africa           Burkina Faso
# 8                  Sub-Saharan Africa  Republic of the Congo
# 9                  Sub-Saharan Africa                Senegal
# 10                               Asia             Kyrgyzstan

# %%
df[['Country','Units Sold']]
# Out:
#                   Country  Units Sold
# 0                  Tuvalu      9925.0
# 1                 Grenada      2804.0
# 2                  Russia      1779.0
# 3   Sao Tome and Principe         NaN
# 4                  Rwanda         NaN
# 5         Solomon Islands         NaN
# 6                  Angola         NaN
# 7            Burkina Faso         NaN
# 8   Republic of the Congo         NaN
# 9                 Senegal         NaN
# 10             Kyrgyzstan       124.0

# %%
df.mean()
# Out:
# Order ID      5.782718e+08
# Units Sold    3.658000e+03
# dtype: float64

# %% [markdown]
# ## Column Addition

# %%
df1=read_csv("E:\Records2.csv",usecols=[0,1]).head(6)
df1
# Out:
#                               Region                Country
# 0              Australia and Oceania                 Tuvalu
# 1  Central America and the Caribbean                Grenada
# 2                             Europe                 Russia
# 3                 Sub-Saharan Africa  Sao Tome and Principe
# 4                 Sub-Saharan Africa                 Rwanda
# 5              Australia and Oceania        Solomon Islands

# %%
df1['Population']=[10000,12000,132000,896789,345690,23444]
df1
# Out:
#                               Region                Country  Population
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444

# %%
df1.insert(3,'Currency',['AUS-USD','USD','EUR','AF-USD','AF-USD','AUS-USD'])
df1
# Out:
#                               Region                Country  Population  \
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444
#
#   Currency
# 0  AUS-USD
# 1      USD
# 2      EUR
# 3   AF-USD
# 4   AF-USD
# 5  AUS-USD

# %%
df1
# Out:
#                               Region                Country  Population  \
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444
#
#   Currency
# 0  AUS-USD
# 1      USD
# 2      EUR
# 3   AF-USD
# 4   AF-USD
# 5  AUS-USD

# %% [markdown]
# ## Column Deletion

# %%
df1.drop('Currency',axis=1)
# Out:
#                               Region                Country  Population
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444

# %%
df1
# Out:
#                               Region                Country  Population  \
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444
#
#   Currency
# 0  AUS-USD
# 1      USD
# 2      EUR
# 3   AF-USD
# 4   AF-USD
# 5  AUS-USD

# %% [markdown]
# # Row

# %% [markdown]
# ## Row Selection

# %%
df1.loc[[0,1,2]]
# Out:
#                               Region  Country  Population Currency
# 0              Australia and Oceania   Tuvalu       10000  AUS-USD
# 1  Central America and the Caribbean  Grenada       12000      USD
# 2                             Europe   Russia      132000      EUR

# %%
df1.loc[0,'Region']
# Out:
# 'Australia and Oceania'

# %%
df1.loc[1,'Country']
# Out:
# 'Grenada'

# %%
df1.loc[2,'Currency']
# Out:
# 'EUR'

# %% [markdown]
# ## Row Additon

# %% [markdown]
# ### Append() method is used to add row to existing Data Frame

# %%
df1
# Out:
#                               Region                Country  Population  \
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444
#
#   Currency
# 0  AUS-USD
# 1      USD
# 2      EUR
# 3   AF-USD
# 4   AF-USD
# 5  AUS-USD

# %%
df2=DataFrame([{'Region':'Delhi','Country':'India','Population':200000,'Currency':'INR'}])
df1.append(df2,ignore_index=True)
df1
# Out:
#                               Region                Country  Population  \
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444
# 6                      Uttar Pradesh                  India     2000000
# 7                      Uttar Pradesh                  India     2000000
# 8                      Uttar Pradesh                  India     2000000
#
#   Currency
# 0  AUS-USD
# 1      USD
# 2      EUR
# 3   AF-USD
# 4   AF-USD
# 5  AUS-USD
# 6      INR
# 7      INR
# 8      INR

# %%
df2=DataFrame([{'Region':'Uttar Pradesh','Country':'India','Population':2000000,'Currency':'INR'}])
df1=df1.append(df2,ignore_index=True)
df1
# Out:
#                               Region                Country  Population  \
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444
# 6                      Uttar Pradesh                  India     2000000
# 7                      Uttar Pradesh                  India     2000000
#
#   Currency
# 0  AUS-USD
# 1      USD
# 2      EUR
# 3   AF-USD
# 4   AF-USD
# 5  AUS-USD
# 6      INR
# 7      INR

# %%
df1
# Out:
#                               Region                Country  Population  \
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444
# 6                      Uttar Pradesh                  India     2000000
# 7                      Uttar Pradesh                  India     2000000
# 8                      Uttar Pradesh                  India     2000000
# 9                      Uttar Pradesh                  India     2000000
#
#   Currency
# 0  AUS-USD
# 1      USD
# 2      EUR
# 3   AF-USD
# 4   AF-USD
# 5  AUS-USD
# 6      INR
# 7      INR
# 8      INR
# 9      INR

# %% [markdown]
# ## Row Deletion

# %%
df1=df1.drop(9)
df1
# Out:
#                               Region                Country  Population  \
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444
# 6                      Uttar Pradesh                  India     2000000
# 7                      Uttar Pradesh                  India     2000000
# 8                      Uttar Pradesh                  India     2000000
#
#   Currency
# 0  AUS-USD
# 1      USD
# 2      EUR
# 3   AF-USD
# 4   AF-USD
# 5  AUS-USD
# 6      INR
# 7      INR
# 8      INR

# %%
df1=df1.drop([7,8])

# %%
df1
# Out:
#                               Region                Country  Population  \
# 0              Australia and Oceania                 Tuvalu       10000
# 1  Central America and the Caribbean                Grenada       12000
# 2                             Europe                 Russia      132000
# 3                 Sub-Saharan Africa  Sao Tome and Principe      896789
# 4                 Sub-Saharan Africa                 Rwanda      345690
# 5              Australia and Oceania        Solomon Islands       23444
# 6                      Uttar Pradesh                  India     2000000
#
#   Currency
# 0  AUS-USD
# 1      USD
# 2      EUR
# 3   AF-USD
# 4   AF-USD
# 5  AUS-USD
# 6      INR
