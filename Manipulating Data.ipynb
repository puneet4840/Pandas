# %% [markdown]
# # Sort Values

# %% [markdown]
# ## Sort_values() method is used to sord the data of Data Frame.

# %%
from pandas import *

# %%
df1=read_csv("E:\Records.csv").head(6)
df1
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H   5/28/2010  669165933   6/27/2010        9925
# 1        Online              C   8/22/2012  963881480   9/15/2012        2804
# 2       Offline              L  05-02-2014  341417157  05-08-2014        1779
# 3        Online              C   6/20/2014  514321792  07-05-2014        8102
# ...

# %%
df2=df1[['Units Sold','Unit Price']]
df2
# Out:
#    Units Sold  Unit Price
# 0        9925      255.28
# 1        2804      205.70
# 2        1779      651.21
# 3        8102        9.33
# 4        5062      651.21
# 5        2974      255.28

# %%
df2.sort_values(by='Units Sold')
# Out:
#    Units Sold  Unit Price
# 2        1779      651.21
# 1        2804      205.70
# 5        2974      255.28
# 4        5062      651.21
# 3        8102        9.33
# 0        9925      255.28

# %%
df2.sort_values(by='Unit Price')
# Out:
#    Units Sold  Unit Price
# 3        8102        9.33
# 1        2804      205.70
# 0        9925      255.28
# 5        2974      255.28
# 2        1779      651.21
# 4        5062      651.21
